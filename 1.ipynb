# %%
class Test:
    @staticmethod
    def assert_equals(a, b, *args, **kwargs):
        assert a == b
        print('Passed')

# %% [markdown]
# 1  https://edabit.com/challenge/gt9LLufDCMHKMioh2
# (10)

# %%
def stutter(word):
	return word[:2]+"... "+word[:2]+"... "+word+"?"

# %%
actual_param, expected_param = [
	"increasing", "adventures", "enticing", "unacceptable", "accountable", "incredible", "exquisite",
	"am", "enduring", "outstanding", "astonishing", "astounding", "impressive", "revolutionize",
	"recurring", "recollection", "so", "gorgeous", "captivating"
], [
	"in... in... increasing?", "ad... ad... adventures?", "en... en... enticing?", "un... un... unacceptable?",
    "ac... ac... accountable?", "in... in... incredible?", "ex... ex... exquisite?", "am... am... am?",
    "en... en... enduring?", "ou... ou... outstanding?", "as... as... astonishing?", "as... as... astounding?",
    "im... im... impressive?", "re... re... revolutionize?", "re... re... recurring?", "re... re... recollection?",
    "so... so... so?", "go... go... gorgeous?", "ca... ca... captivating?",
]
for i, w in enumerate(actual_param):
	Test.assert_equals(stutter(w), expected_param[i])
# Out:
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed

# %% [markdown]
# 2  https://edabit.com/challenge/cXnkmRdxqJrwdsP4n
# (10)

# %%
def dis(price, discount):
	return price*(100-discount)*0.01

# %%
Test.assert_equals(dis(100, 75), 25)
Test.assert_equals(dis(211, 50), 105.5)
Test.assert_equals(dis(593, 61), 231.27)
Test.assert_equals(dis(1693, 80), 338.6)
Test.assert_equals(dis(700, 10), 630)
# Out:
# Passed
# Passed
# Passed
# Passed
# Passed

# %% [markdown]
# 3  https://edabit.com/challenge/8pDH2SRutPoaQghgc
# (10)

# %%
d = {'Darth Vader':'father',
				'Leia':'sister',
				'Han': 'brother in law',
				'R2D2':'droid'
				}
def relation_to_luke(name):
	  return "Luke, I am your "+ d[name]+"."

# %%
Test.assert_equals(relation_to_luke("Darth Vader"), "Luke, I am your father.")
Test.assert_equals(relation_to_luke("Leia"), "Luke, I am your sister.")
Test.assert_equals(relation_to_luke("Han"), "Luke, I am your brother in law.")
Test.assert_equals(relation_to_luke("R2D2"), "Luke, I am your droid.")
# Out:
# Passed
# Passed
# Passed
# Passed

# %% [markdown]
# 4  https://edabit.com/challenge/tgEWKRQD8hu5dD3pX
# (10)

# %%
def mood_today(mood=""):
    if mood=="":
          mood = "neutral"
    return "Today, I am feeling "+ mood

# %%
Test.assert_equals(mood_today("happy"), "Today, I am feeling happy")
Test.assert_equals(mood_today("sad"), "Today, I am feeling sad")
Test.assert_equals(mood_today("very happy"), "Today, I am feeling very happy")
Test.assert_equals(mood_today("rather empty inside"), "Today, I am feeling rather empty inside")
Test.assert_equals(mood_today("confused"), "Today, I am feeling confused")
Test.assert_equals(mood_today(), "Today, I am feeling neutral")
# Out:
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed

# %% [markdown]
# 5  https://edabit.com/challenge/uKPc5faEzQkMwLYPP
# (10)

# %%
import math

def end_corona(recovers, new_cases, active_cases):
    return math.ceil((active_cases)/(recovers-new_cases))

# %%
Test.assert_equals(end_corona(4000, 2000, 77000), 39)
Test.assert_equals(end_corona(3000, 2000, 50699), 51)
Test.assert_equals(end_corona(30000, 25000, 390205), 79)
Test.assert_equals(end_corona(260000, 255000, 20511691), 4103)
# Out:
# Passed
# Passed
# Passed
# Passed

# %% [markdown]
# 6  https://edabit.com/challenge/2X2uZysLJ3CpsxLDD
# (10)

# %%
import math

def radians_to_degrees(rad):
  return round(rad*180/ math.pi, 1)

# %%
Test.assert_equals(radians_to_degrees(1), 57.3)
Test.assert_equals(radians_to_degrees(5), 286.5)
Test.assert_equals(radians_to_degrees(7), 401.1)
Test.assert_equals(radians_to_degrees(60), 3437.7)
Test.assert_equals(radians_to_degrees(100), 5729.6)
Test.assert_equals(radians_to_degrees(180), 10313.2)
# Out:
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed

# %% [markdown]
# 7  https://edabit.com/challenge/2zKetgAJp4WRFXiDT
# (20)

# %%
def number_length(num):
  len = 1
  while num >= 10:
    num /=10
    len+=1
  return len

# %%
Test.assert_equals(number_length(10), 2)
Test.assert_equals(number_length(5000), 4)
Test.assert_equals(number_length(0), 1)
Test.assert_equals(number_length(4039182), 7)
Test.assert_equals(number_length(9999999999999999), 16)
Test.assert_equals(number_length(1), 1)
Test.assert_equals(number_length(777777777777777777777777777777), 30)
# Out:
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed

# %% [markdown]
# 8  https://edabit.com/challenge/xRMQG4Sxewx5agDRr (20)

# %%
def find_highest(lst):
  max = lst[0]
  for x in lst:
    if x > max:
      max = x
  return max

# %%
Test.assert_equals(find_highest([8]), 8)
Test.assert_equals(find_highest([-1, 3, 5, 6, 99, 12, 2]), 99)
Test.assert_equals(find_highest([0, 12, 4, 87]), 87)
# Out:
# Passed
# Passed
# Passed

# %% [markdown]
# 9  https://edabit.com/challenge/5XXXppAdfcGaootD9 (20)

# %%
def sum_odd_and_even(lst):
  odd = 0
  even = 0
  for x in lst:
    if (x %2) == 0:
      even+=x
    else:
      odd+=x
  return [even, odd]

# %%
Test.assert_equals(sum_odd_and_even([1, 2, 3, 4, 5, 6]), [12, 9])
Test.assert_equals(sum_odd_and_even([-1, -2, -3, -4, -5, -6]), [-12, -9])
Test.assert_equals(sum_odd_and_even([0, 0]), [0, 0])
Test.assert_equals(sum_odd_and_even([]), [0, 0])
# Out:
# Passed
# Passed
# Passed
# Passed

# %% [markdown]
# 10  https://edabit.com/challenge/zkKNmC66ASvSm5wJA  (40)

# %%
def perimeter(l, num):
  return (l=="c")*(6.28 * num) + (l =="s")*(4*num)

# %%
Test.assert_equals(perimeter("s", 1), 4)
Test.assert_equals(perimeter("s", 4), 16)
Test.assert_equals(perimeter("s", 9), 36)
Test.assert_equals(perimeter("s", 13), 52)
Test.assert_equals(perimeter("s", 30), 120)
Test.assert_equals(perimeter("c", 1), 6.28)
Test.assert_equals(perimeter("c", 4), 25.12)
Test.assert_equals(perimeter("c", 9), 56.52)
Test.assert_equals(perimeter("c", 13), 81.64)
Test.assert_equals(perimeter("c", 30), 188.4)
# Out:
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
# Passed
